# %%
# @title Importing modules
import pandas as pd
import numpy as np
import os
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , confusion_matrix, precision_score, recall_score, f1_score , cohen_kappa_score
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras import layers
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# @title Define labels and our dataframe
data = pd.DataFrame(columns=['image_path', 'label'])

labels = {'/kaggle/input/satellite-image-classification/data/cloudy' : 'Cloudy',
          '/kaggle/input/satellite-image-classification/data/desert' : 'Desert',
          '/kaggle/input/satellite-image-classification/data/green_area' : 'Green_Area',
          '/kaggle/input/satellite-image-classification/data/water' : 'Water',
           }

# %%
# @title To append the data into the dataframe with our labels and paths

for folder in labels:
    for image_name in os.listdir(folder):
        image_path = os.path.join(folder, image_name)
        label = labels[folder]
        data = pd.concat([data, pd.DataFrame({'image_path': [image_path], 'label': [label]})], ignore_index=True)

# %%
# @title Create the csv file with our data

data.to_csv('dataSet.csv', index=False)

# %%
# @title Read our CSV file

df = pd.read_csv("/kaggle/working/dataSet.csv")
print(df)
# Out:
#                                              image_path   label
# 0     /kaggle/input/satellite-image-classification/d...  Cloudy
# 1     /kaggle/input/satellite-image-classification/d...  Cloudy
# 2     /kaggle/input/satellite-image-classification/d...  Cloudy
# 3     /kaggle/input/satellite-image-classification/d...  Cloudy
# 4     /kaggle/input/satellite-image-classification/d...  Cloudy
# ...                                                 ...     ...
# 5626  /kaggle/input/satellite-image-classification/d...   Water
# 5627  /kaggle/input/satellite-image-classification/d...   Water
# 5628  /kaggle/input/satellite-image-classification/d...   Water
# 5629  /kaggle/input/satellite-image-classification/d...   Water
# 5630  /kaggle/input/satellite-image-classification/d...   Water
#
# [5631 rows x 2 columns]

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2)

# %%
# @title Cross-validation, and finding the best deployable model

# Define the number of folds for cross-validation
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Track best hyperparameters and performance
best_accuracy = 0.0
best_model = None
best_history = None

# Iterate over the folds
for fold, (train_index, test_index) in enumerate(skf.split(df['image_path'], df['label']), start = 1):
    print(f"Fold {fold}/{n_splits}")

    # Split the data into training and testing sets for this fold
    train_df, test_df = df.iloc[train_index], df.iloc[test_index]

    # the rescale is done to make the training faster if each pixel of each image is
    # normalized to be between 0 and 1 ans it's no need to normalize it between -1 and 1
    train_datagen = ImageDataGenerator(rescale=1./255,
                                      shear_range=0.2,
                                      zoom_range=0.2,
                                      horizontal_flip=True,
                                      rotation_range=45,
                                      vertical_flip=True,
                                      fill_mode='nearest')

    #here no need to do anything more than just rescaling
    test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_dataframe(dataframe=train_df,
                                                        x_col="image_path",
                                                        y_col="label",
                                                        target_size=(255, 255),
                                                        batch_size=32,
                                                        class_mode="categorical")

    test_generator = test_datagen.flow_from_dataframe(dataframe=test_df,
                                                      x_col="image_path",
                                                      y_col="label",
                                                      target_size=(255, 255),
                                                      batch_size=32,
                                                      class_mode="categorical")
    #Creating transfer learning model
    
    resnet_model = Sequential()
    
    pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(255,255,3),
                   pooling='max',classes=4,
                   weights='imagenet')
    
    for layer in pretrained_model.layers:
            layer.trainable=False

    resnet_model.add(pretrained_model)
    resnet_model.add(Flatten())
    resnet_model.add(Dense(512, activation='relu'))
    #Add an output Dense layer with 4 neurones corresponding to the number of classes present in our dataset
    resnet_model.add(Dense(4, activation='softmax'))
    

    # Compile and train the model
    resnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    # print("Number of samples in train_generator:", len(train_generator))
    # print("Number of samples in train_df['label']:", len(train_df['label']))
    history = resnet_model.fit(train_generator, epochs=50, validation_data=test_generator, callbacks=[early_stopping, reduce_lr])

    # Evaluate the model on the test set for this fold
    test_loss, test_accuracy = resnet_model.evaluate(test_generator)
    print(f"Test Accuracy for Fold {fold}: {test_accuracy}")

    # Check if this fold had the best performance
    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        best_model = resnet_model  # Save the model with the best performance
        best_history = history  # Save the history of the best fold
# Out:
# Fold 1/5
# Found 4504 validated image filenames belonging to 4 classes.
# Found 1127 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 141/141 [==============================] - 74s 495ms/step - loss: 2.0817 - accuracy: 0.3606 - val_loss: 1.1045 - val_accuracy: 0.5138 - lr: 0.0010
# Epoch 2/50
# 141/141 [==============================] - 70s 496ms/step - loss: 1.1272 - accuracy: 0.4869 - val_loss: 0.8637 - val_accuracy: 0.4836 - lr: 0.0010
# Epoch 3/50
# 141/141 [==============================] - 72s 507ms/step - loss: 0.9245 - accuracy: 0.5608 - val_loss: 0.7581 - val_accuracy: 0.5785 - lr: 0.0010
# Epoch 4/50
# 141/141 [==============================] - 70s 493ms/step - loss: 0.7947 - accuracy: 0.6092 - val_loss: 0.6966 - val_accuracy: 0.5324 - lr: 0.0010
# Epoch 5/50
# 141/141 [==============================] - 70s 495ms/step - loss: 0.8750 - accuracy: 0.5710 - val_loss: 0.6650 - val_accuracy: 0.6318 - lr: 0.0010
# Epoch 6/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.6975 - accuracy: 0.6365 - val_loss: 0.9815 - val_accuracy: 0.4862 - lr: 0.0010
# Epoch 7/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.6727 - accuracy: 0.6563 - val_loss: 0.7653 - val_accuracy: 0.5111 - lr: 0.0010
# Epoch 8/50
# 141/141 [==============================] - 70s 499ms/step - loss: 0.5826 - accuracy: 0.7655 - val_loss: 0.5599 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 9/50
# 141/141 [==============================] - 69s 489ms/step - loss: 0.5699 - accuracy: 0.7931 - val_loss: 0.5754 - val_accuracy: 0.7356 - lr: 1.0000e-04
# Epoch 10/50
# 141/141 [==============================] - 70s 497ms/step - loss: 0.5637 - accuracy: 0.7933 - val_loss: 0.5579 - val_accuracy: 0.8660 - lr: 1.0000e-04
# Epoch 11/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.5584 - accuracy: 0.7889 - val_loss: 0.5499 - val_accuracy: 0.7675 - lr: 1.0000e-04
# Epoch 12/50
# 141/141 [==============================] - 70s 498ms/step - loss: 0.5560 - accuracy: 0.7871 - val_loss: 0.5493 - val_accuracy: 0.7853 - lr: 1.0000e-04
# Epoch 13/50
# 141/141 [==============================] - 71s 500ms/step - loss: 0.5526 - accuracy: 0.7824 - val_loss: 0.5399 - val_accuracy: 0.8980 - lr: 1.0000e-04
# Epoch 14/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.5477 - accuracy: 0.7620 - val_loss: 0.5395 - val_accuracy: 0.6903 - lr: 1.0000e-04
# Epoch 15/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.5463 - accuracy: 0.7993 - val_loss: 0.5280 - val_accuracy: 0.7578 - lr: 1.0000e-04
# Epoch 16/50
# 141/141 [==============================] - 70s 499ms/step - loss: 0.5389 - accuracy: 0.7922 - val_loss: 0.5213 - val_accuracy: 0.7941 - lr: 1.0000e-04
# Epoch 17/50
# 141/141 [==============================] - 69s 487ms/step - loss: 0.5352 - accuracy: 0.7738 - val_loss: 0.5261 - val_accuracy: 0.7613 - lr: 1.0000e-04
# Epoch 18/50
# 141/141 [==============================] - 70s 497ms/step - loss: 0.5301 - accuracy: 0.7800 - val_loss: 0.5395 - val_accuracy: 0.7418 - lr: 1.0000e-04
# Epoch 19/50
# 141/141 [==============================] - 70s 492ms/step - loss: 0.5153 - accuracy: 0.8703 - val_loss: 0.5111 - val_accuracy: 0.9033 - lr: 1.0000e-05
# Epoch 20/50
# 141/141 [==============================] - 70s 497ms/step - loss: 0.5127 - accuracy: 0.8799 - val_loss: 0.5091 - val_accuracy: 0.8634 - lr: 1.0000e-05
# Epoch 21/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.5120 - accuracy: 0.8712 - val_loss: 0.5142 - val_accuracy: 0.8066 - lr: 1.0000e-05
# Epoch 22/50
# 141/141 [==============================] - 69s 488ms/step - loss: 0.5095 - accuracy: 0.8646 - val_loss: 0.5028 - val_accuracy: 0.8909 - lr: 1.0000e-05
# Epoch 23/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.5118 - accuracy: 0.8741 - val_loss: 0.5021 - val_accuracy: 0.9264 - lr: 1.0000e-05
# Epoch 24/50
# 141/141 [==============================] - 69s 488ms/step - loss: 0.5101 - accuracy: 0.8686 - val_loss: 0.5141 - val_accuracy: 0.7746 - lr: 1.0000e-05
# Epoch 25/50
# 141/141 [==============================] - 69s 492ms/step - loss: 0.5088 - accuracy: 0.8803 - val_loss: 0.5054 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 26/50
# 141/141 [==============================] - 70s 494ms/step - loss: 0.5077 - accuracy: 0.9085 - val_loss: 0.5026 - val_accuracy: 0.8971 - lr: 1.0000e-06
# Epoch 27/50
# 141/141 [==============================] - 68s 482ms/step - loss: 0.5059 - accuracy: 0.9005 - val_loss: 0.5032 - val_accuracy: 0.8900 - lr: 1.0000e-06
# Epoch 28/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.5056 - accuracy: 0.8956 - val_loss: 0.5029 - val_accuracy: 0.8926 - lr: 1.0000e-07
# 36/36 [==============================] - 4s 122ms/step - loss: 0.5021 - accuracy: 0.9264
# Test Accuracy for Fold 1: 0.9263531565666199
# Fold 2/5
# Found 4505 validated image filenames belonging to 4 classes.
# Found 1126 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 141/141 [==============================] - 75s 501ms/step - loss: 1.9779 - accuracy: 0.3496 - val_loss: 1.2454 - val_accuracy: 0.5284 - lr: 0.0010
# Epoch 2/50
# 141/141 [==============================] - 69s 491ms/step - loss: 1.0854 - accuracy: 0.4897 - val_loss: 1.0957 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 3/50
# 141/141 [==============================] - 71s 501ms/step - loss: 0.9371 - accuracy: 0.5412 - val_loss: 0.8149 - val_accuracy: 0.6146 - lr: 0.0010
# Epoch 4/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.7835 - accuracy: 0.5827 - val_loss: 0.7630 - val_accuracy: 0.6234 - lr: 0.0010
# Epoch 5/50
# 141/141 [==============================] - 69s 487ms/step - loss: 0.7408 - accuracy: 0.6064 - val_loss: 0.6275 - val_accuracy: 0.7380 - lr: 0.0010
# Epoch 6/50
# 141/141 [==============================] - 69s 488ms/step - loss: 0.6968 - accuracy: 0.6402 - val_loss: 0.6053 - val_accuracy: 0.7593 - lr: 0.0010
# Epoch 7/50
# 141/141 [==============================] - 70s 496ms/step - loss: 0.6665 - accuracy: 0.6579 - val_loss: 0.5991 - val_accuracy: 0.7096 - lr: 0.0010
# Epoch 8/50
# 141/141 [==============================] - 70s 496ms/step - loss: 0.6715 - accuracy: 0.6522 - val_loss: 0.7096 - val_accuracy: 0.5631 - lr: 0.0010
# Epoch 9/50
# 141/141 [==============================] - 72s 507ms/step - loss: 0.5919 - accuracy: 0.6890 - val_loss: 0.6451 - val_accuracy: 0.7194 - lr: 0.0010
# Epoch 10/50
# 141/141 [==============================] - 70s 494ms/step - loss: 0.5359 - accuracy: 0.7993 - val_loss: 0.5081 - val_accuracy: 0.8037 - lr: 1.0000e-04
# Epoch 11/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.5212 - accuracy: 0.8291 - val_loss: 0.5070 - val_accuracy: 0.8206 - lr: 1.0000e-04
# Epoch 12/50
# 141/141 [==============================] - 70s 492ms/step - loss: 0.5195 - accuracy: 0.8353 - val_loss: 0.4933 - val_accuracy: 0.9467 - lr: 1.0000e-04
# Epoch 13/50
# 141/141 [==============================] - 69s 492ms/step - loss: 0.5146 - accuracy: 0.8306 - val_loss: 0.4903 - val_accuracy: 0.8153 - lr: 1.0000e-04
# Epoch 14/50
# 141/141 [==============================] - 70s 493ms/step - loss: 0.5059 - accuracy: 0.8386 - val_loss: 0.4970 - val_accuracy: 0.8179 - lr: 1.0000e-04
# Epoch 15/50
# 141/141 [==============================] - 70s 500ms/step - loss: 0.5058 - accuracy: 0.8511 - val_loss: 0.4878 - val_accuracy: 0.8481 - lr: 1.0000e-04
# Epoch 16/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.4991 - accuracy: 0.8517 - val_loss: 0.4761 - val_accuracy: 0.8952 - lr: 1.0000e-04
# Epoch 17/50
# Epoch 29/50
# 141/141 [==============================] - 68s 485ms/step - loss: 0.4187 - accuracy: 0.9472 - val_loss: 0.3967 - val_accuracy: 0.9307 - lr: 1.0000e-06
# Epoch 30/50
# 141/141 [==============================] - 69s 492ms/step - loss: 0.4166 - accuracy: 0.9445 - val_loss: 0.3964 - val_accuracy: 0.9352 - lr: 1.0000e-06
# Epoch 31/50
# 141/141 [==============================] - 69s 489ms/step - loss: 0.4204 - accuracy: 0.9394 - val_loss: 0.3961 - val_accuracy: 0.9361 - lr: 1.0000e-07
# Epoch 32/50
# 141/141 [==============================] - 69s 488ms/step - loss: 0.4159 - accuracy: 0.9450 - val_loss: 0.3959 - val_accuracy: 0.9378 - lr: 1.0000e-07
# Epoch 33/50
# 141/141 [==============================] - 70s 493ms/step - loss: 0.4155 - accuracy: 0.9503 - val_loss: 0.3959 - val_accuracy: 0.9378 - lr: 1.0000e-08
# 36/36 [==============================] - 4s 119ms/step - loss: 0.3949 - accuracy: 0.9476
# Test Accuracy for Fold 3: 0.9476021528244019
# Fold 4/5
# Found 4505 validated image filenames belonging to 4 classes.
# Found 1126 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 141/141 [==============================] - 75s 501ms/step - loss: 2.0195 - accuracy: 0.2990 - val_loss: 1.3278 - val_accuracy: 0.2869 - lr: 0.0010
# Epoch 2/50
# 141/141 [==============================] - 69s 489ms/step - loss: 1.1907 - accuracy: 0.4666 - val_loss: 1.1283 - val_accuracy: 0.6368 - lr: 0.0010
# Epoch 3/50
# 141/141 [==============================] - 70s 495ms/step - loss: 0.9625 - accuracy: 0.5307 - val_loss: 1.0987 - val_accuracy: 0.6892 - lr: 0.0010
# Epoch 4/50
# 141/141 [==============================] - 70s 495ms/step - loss: 0.8653 - accuracy: 0.5889 - val_loss: 0.7151 - val_accuracy: 0.7300 - lr: 0.0010
# Epoch 5/50
# 141/141 [==============================] - 69s 487ms/step - loss: 0.7780 - accuracy: 0.5862 - val_loss: 0.6426 - val_accuracy: 0.6279 - lr: 0.0010
# Epoch 6/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.7099 - accuracy: 0.6402 - val_loss: 0.6254 - val_accuracy: 0.7487 - lr: 0.0010
# Epoch 7/50
# 141/141 [==============================] - 69s 486ms/step - loss: 0.6808 - accuracy: 0.6517 - val_loss: 0.6398 - val_accuracy: 0.6954 - lr: 0.0010
# Epoch 8/50
# 141/141 [==============================] - 70s 495ms/step - loss: 0.6515 - accuracy: 0.6721 - val_loss: 0.5304 - val_accuracy: 0.8686 - lr: 0.0010
# Epoch 9/50
# 141/141 [==============================] - 69s 486ms/step - loss: 0.6367 - accuracy: 0.6699 - val_loss: 0.5090 - val_accuracy: 0.7957 - lr: 0.0010
# Epoch 10/50
# 141/141 [==============================] - 70s 496ms/step - loss: 0.6522 - accuracy: 0.6562 - val_loss: 0.6405 - val_accuracy: 0.5933 - lr: 0.0010
# Epoch 11/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.4675 - accuracy: 0.9125 - val_loss: 0.4378 - val_accuracy: 0.8908 - lr: 1.0000e-05
# Epoch 29/50
# 141/141 [==============================] - 70s 498ms/step - loss: 0.4661 - accuracy: 0.9119 - val_loss: 0.4400 - val_accuracy: 0.9121 - lr: 1.0000e-05
# Epoch 30/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.4654 - accuracy: 0.9068 - val_loss: 0.4352 - val_accuracy: 0.9236 - lr: 1.0000e-05
# Epoch 31/50
# 141/141 [==============================] - 69s 489ms/step - loss: 0.4653 - accuracy: 0.9021 - val_loss: 0.4358 - val_accuracy: 0.8961 - lr: 1.0000e-05
# Epoch 32/50
# 141/141 [==============================] - 69s 491ms/step - loss: 0.4645 - accuracy: 0.9105 - val_loss: 0.4379 - val_accuracy: 0.9272 - lr: 1.0000e-05
# Epoch 33/50
# 141/141 [==============================] - 68s 483ms/step - loss: 0.4631 - accuracy: 0.9279 - val_loss: 0.4360 - val_accuracy: 0.9130 - lr: 1.0000e-06
# Epoch 34/50
# 141/141 [==============================] - 68s 484ms/step - loss: 0.4645 - accuracy: 0.9272 - val_loss: 0.4362 - val_accuracy: 0.9076 - lr: 1.0000e-06
# Epoch 35/50
# 141/141 [==============================] - 69s 490ms/step - loss: 0.4612 - accuracy: 0.9261 - val_loss: 0.4360 - val_accuracy: 0.9121 - lr: 1.0000e-07
# 36/36 [==============================] - 5s 123ms/step - loss: 0.4352 - accuracy: 0.9236
# Test Accuracy for Fold 4: 0.9236234426498413
# Fold 5/5
# Found 4505 validated image filenames belonging to 4 classes.
# Found 1126 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 141/141 [==============================] - 73s 494ms/step - loss: 1.7414 - accuracy: 0.3694 - val_loss: 1.0888 - val_accuracy: 0.4964 - lr: 0.0010
# Epoch 2/50
# 141/141 [==============================] - 68s 480ms/step - loss: 1.0166 - accuracy: 0.5196 - val_loss: 0.9559 - val_accuracy: 0.5009 - lr: 0.0010
# Epoch 3/50
# 141/141 [==============================] - 69s 486ms/step - loss: 0.9047 - accuracy: 0.5498 - val_loss: 1.1204 - val_accuracy: 0.4769 - lr: 0.0010
# Epoch 4/50
# 141/141 [==============================] - 70s 499ms/step - loss: 0.7943 - accuracy: 0.5727 - val_loss: 0.8153 - val_accuracy: 0.4920 - lr: 0.0010
# Epoch 5/50
# 141/141 [==============================] - 70s 496ms/step - loss: 0.7746 - accuracy: 0.5782 - val_loss: 0.7366 - val_accuracy: 0.6057 - lr: 0.0010
# Epoch 6/50
# 141/141 [==============================] - 70s 494ms/step - loss: 0.6877 - accuracy: 0.6291 - val_loss: 0.8142 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 7/50
# 141/141 [==============================] - 70s 493ms/step - loss: 0.6691 - accuracy: 0.6486 - val_loss: 0.7151 - val_accuracy: 0.5275 - lr: 0.0010
# Epoch 8/50
# 141/141 [==============================] - 69s 488ms/step - loss: 0.6603 - accuracy: 0.6488 - val_loss: 0.6863 - val_accuracy: 0.6465 - lr: 0.0010
# Epoch 26/50
# 141/141 [==============================] - 72s 510ms/step - loss: 0.4118 - accuracy: 0.9350 - val_loss: 0.4035 - val_accuracy: 0.9041 - lr: 1.0000e-05
# Epoch 27/50
# 141/141 [==============================] - 71s 502ms/step - loss: 0.4090 - accuracy: 0.9476 - val_loss: 0.3999 - val_accuracy: 0.9440 - lr: 1.0000e-06
# Epoch 28/50
# 141/141 [==============================] - 71s 502ms/step - loss: 0.4067 - accuracy: 0.9505 - val_loss: 0.3995 - val_accuracy: 0.9458 - lr: 1.0000e-06
# Epoch 29/50
# 141/141 [==============================] - 70s 496ms/step - loss: 0.4104 - accuracy: 0.9447 - val_loss: 0.3996 - val_accuracy: 0.9467 - lr: 1.0000e-07
# 36/36 [==============================] - 4s 118ms/step - loss: 0.3984 - accuracy: 0.9520
# Test Accuracy for Fold 5: 0.9520426392555237

# %%
best_accuracy
# Out:
# 0.9662522077560425

# %%
# Split the whole dataset into training and testing sets
final_train_df, final_test_df = train_test_split(df, test_size=0.2, random_state=42)

# Define the ImageDataGenerator for the training dataset
final_train_datagen = ImageDataGenerator(rescale=1./255,
                                         shear_range=0.2,
                                         zoom_range=0.2,
                                         horizontal_flip=True,
                                         rotation_range=45,
                                         vertical_flip=True,
                                         fill_mode='nearest')

# Define the ImageDataGenerator for the testing dataset
final_test_datagen = ImageDataGenerator(rescale=1./255)

# Create the full dataset generator to be used with the best model after cross-validation
final_train_dataset_generator = final_train_datagen.flow_from_dataframe(dataframe=final_train_df,
                                                                  x_col="image_path",
                                                                  y_col="label",
                                                                  target_size=(255, 255),
                                                                  batch_size=128,
                                                                  class_mode="categorical")


final_test_dataset_generator = final_test_datagen.flow_from_dataframe(dataframe=final_test_df,
                                                  x_col="image_path",
                                                  y_col="label",
                                                  target_size=(255, 255),
                                                  batch_size=128,
                                                  class_mode="categorical")
# Out:
# Found 4504 validated image filenames belonging to 4 classes.
# Found 1127 validated image filenames belonging to 4 classes.

# %%
# Train the best model on the entire dataset

best_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
final_history = best_model.fit(final_train_dataset_generator, epochs=50, validation_data=final_test_dataset_generator, callbacks=[reduce_lr,early_stopping])
# Out:
# Epoch 1/50
# 36/36 [==============================] - 84s 2s/step - loss: 0.8390 - accuracy: 0.6352 - val_loss: 0.5699 - val_accuracy: 0.6832 - lr: 0.0010
# Epoch 2/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5593 - accuracy: 0.7706 - val_loss: 0.5169 - val_accuracy: 0.8172 - lr: 0.0010
# Epoch 3/50
# 36/36 [==============================] - 74s 2s/step - loss: 0.5549 - accuracy: 0.7780 - val_loss: 0.5181 - val_accuracy: 0.7285 - lr: 0.0010
# Epoch 4/50
# 36/36 [==============================] - 74s 2s/step - loss: 0.5407 - accuracy: 0.7809 - val_loss: 0.5509 - val_accuracy: 0.6752 - lr: 0.0010
# Epoch 5/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5161 - accuracy: 0.8475 - val_loss: 0.4761 - val_accuracy: 0.8545 - lr: 1.0000e-04
# Epoch 6/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5143 - accuracy: 0.8857 - val_loss: 0.4742 - val_accuracy: 0.9521 - lr: 1.0000e-04
# Epoch 7/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5140 - accuracy: 0.8939 - val_loss: 0.4734 - val_accuracy: 0.9432 - lr: 1.0000e-04
# Epoch 8/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5122 - accuracy: 0.8481 - val_loss: 0.4856 - val_accuracy: 0.8261 - lr: 1.0000e-04
# Epoch 9/50
# 36/36 [==============================] - 76s 2s/step - loss: 0.5100 - accuracy: 0.8677 - val_loss: 0.4719 - val_accuracy: 0.9556 - lr: 1.0000e-04
# Epoch 10/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5072 - accuracy: 0.9205 - val_loss: 0.4715 - val_accuracy: 0.9388 - lr: 1.0000e-04
# Epoch 11/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5043 - accuracy: 0.9105 - val_loss: 0.4641 - val_accuracy: 0.8864 - lr: 1.0000e-04
# Epoch 12/50
# 36/36 [==============================] - 76s 2s/step - loss: 0.5016 - accuracy: 0.8848 - val_loss: 0.4804 - val_accuracy: 0.9423 - lr: 1.0000e-04
# Epoch 13/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5046 - accuracy: 0.8777 - val_loss: 0.4912 - val_accuracy: 0.7587 - lr: 1.0000e-04
# Epoch 14/50
# 36/36 [==============================] - 75s 2s/step - loss: 0.5024 - accuracy: 0.8945 - val_loss: 0.4619 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 15/50
# 36/36 [==============================] - 73s 2s/step - loss: 0.5003 - accuracy: 0.9192 - val_loss: 0.4672 - val_accuracy: 0.9521 - lr: 1.0000e-05
# Epoch 16/50
# 36/36 [==============================] - 73s 2s/step - loss: 0.4982 - accuracy: 0.9363 - val_loss: 0.4658 - val_accuracy: 0.9592 - lr: 1.0000e-05
# Epoch 17/50
# 36/36 [==============================] - 74s 2s/step - loss: 0.4999 - accuracy: 0.9460 - val_loss: 0.4647 - val_accuracy: 0.9601 - lr: 1.0000e-06
# Epoch 18/50
# 36/36 [==============================] - 74s 2s/step - loss: 0.4978 - accuracy: 0.9423 - val_loss: 0.4643 - val_accuracy: 0.9592 - lr: 1.0000e-06
# Epoch 19/50
# 36/36 [==============================] - 74s 2s/step - loss: 0.4975 - accuracy: 0.9372 - val_loss: 0.4644 - val_accuracy: 0.9583 - lr: 1.0000e-07

# %%
# @title Save the model as h5 file
# Save the best model for deployment
best_model.save('/kaggle/working/deployable_model.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Use only to delete the deployable model in the working directory in Kaggle
os.remove("/kaggle/working/deployable_model.h5")

# %%
print("Loss function:", best_model.loss)
print("Optimizer:", best_model.optimizer)
print("Metrics:", best_model.metrics_names)
# Out:
# Loss function: categorical_crossentropy
# Optimizer: <keras.src.optimizers.adam.Adam object at 0x7c91903c0040>
# Metrics: ['loss', 'accuracy']

# %%
best_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 512)               1049088
#
#  dense_5 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 24638852 (93.99 MB)
# Trainable params: 1051140 (4.01 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from PIL import Image

plot_model(best_model, to_file='/kaggle/working/cnn_model.png', show_shapes=True, show_layer_names=True)
display(Image.open('/kaggle/working/cnn_model.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=486x546>

# %%
# @title Loss & Accuracy Visualizations
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the loss
ax1.plot(final_history.history['loss'], label='Training Loss')
ax1.plot(final_history.history['val_loss'], label='Validation Loss')
ax1.legend()
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')

# Plot the accuracy
ax2.plot(final_history.history['accuracy'], label='Training Accuracy')
ax2.plot(final_history.history['val_accuracy'], label='Validation Accuracy')
ax2.legend()
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')

# Adjust layout and show the plots
plt.tight_layout()

# Save the figures in the working directory
plt.savefig('LossVal_loss.png')
plt.savefig('AccVal_acc.png')

# Show the plots
plt.show()

# %%
# @title Load model

model = load_model("/kaggle/working/deployable_model.h5")

# %%
#Importing libraries needed for confusion matrix

from sklearn.metrics import confusion_matrix
import numpy as np

# %%
#Store our model's predictions when tested against the test_generator dataset

predictions = model.predict_generator(test_generator)
predictions
# Out:
# /tmp/ipykernel_42/3368414843.py:3: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_generator)
# array([[9.4998088e-03, 1.6488013e-05, 4.5231059e-01, 5.3817314e-01],
#        [3.7365247e-02, 9.6258622e-01, 3.8444388e-05, 1.0051414e-05],
#        [2.4119481e-02, 1.1698154e-04, 5.1628047e-01, 4.5948306e-01],
#        ...,
#        [2.1604276e-01, 7.8358692e-01, 2.2510650e-04, 1.4530835e-04],
#        [2.6816107e-02, 9.7316170e-01, 1.7773704e-05, 4.3495111e-06],
#        [8.0912458e-03, 1.2709568e-05, 4.5144281e-01, 5.4045320e-01]],
#       dtype=float32)

# %%
#test_generator.classes returns the true labels given to the samples in the test_generator

actual_labels = test_generator.classes

# %%
predicted_labels = np.argmax(predictions, axis=1)
predicted_labels
# Out:
# array([3, 1, 2, ..., 1, 1, 3])

# %%
#Generate the confusion matrix array

cm = confusion_matrix(actual_labels, predicted_labels)
cm
# Out:
# array([[78, 65, 83, 74],
#        [61, 34, 76, 55],
#        [75, 74, 67, 84],
#        [87, 57, 72, 84]])

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools

# Define the class names
class_names = ['Cloudy', 'Desert', 'Green_Area', 'Water']


# Confusion matrix

# Plot the confusion matrix as an image
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()

# Add the class labels to the plot
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)

# Add values to the plot
threshold = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black")

plt.tight_layout()
plt.ylabel("True label")
plt.xlabel("Predicted label")
plt.savefig('Confusion Matrix')
plt.show()
